# %%
import numpy as np

import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import networks.layers.trainable_activation as trainable_activation
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
train_act = trainable_activation.TrainableActivation(num_channels=1, vmin=-6 vmax=5, num_weights=31, init="sine", init_scale=1)

# %%
train_act.weight
# Out:
# Parameter containing:
# tensor([ 0.9589,  0.9990,  0.9290,  0.7568,  0.5013,  0.1906, -0.1411, -0.4573,
#         -0.7231, -0.9093, -0.9954, -0.9719, -0.8415, -0.6184, -0.3272,  0.0000,
#          0.3272,  0.6184,  0.8415,  0.9719,  0.9954,  0.9093,  0.7231,  0.4573,
#          0.1411, -0.1906, -0.5013, -0.7568, -0.9290, -0.9990, -0.9589],
#        requires_grad=True)

# %%
x, y = train_act.draw()
x = x.detach().numpy()
y = y.detach().numpy()
plt.scatter(x, y, s=5, marker=".")
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Activation')
plt.grid(True)
plt.show()
